# %% [markdown]
# Linear Registration Example
# ===========================
#
# Author: Nathan Faggian

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
from imreg import register, sampler, model, metric

# %%
from scipy.misc import lena
from scipy import ndimage

# %%
image = lena()
template = ndimage.rotate(image, 30, reshape=False)

# %%
registrator = register.Register(model.Affine, metric.Residual, sampler.Bilinear)

# %%
image = register.RegisterData(image).downsample(8)

template = register.RegisterData(template).downsample(8)

# %%
step, warpedImage, search = registrator.register(
    image,
    template,
    verbose=False,
    )

# %%
# %timeit registrator.register(image, template, verbose=False)
# Out:
# 10 loops, best of 3: 133 ms per loop

# %%
fix, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 8))

ax1.imshow(image.data)
_ = ax1.set_title('image')

ax2.imshow(template.data)
_ = ax2.set_title('template')

ax3.imshow(warpedImage)
_ = ax3.set_title('image aligned to template')
